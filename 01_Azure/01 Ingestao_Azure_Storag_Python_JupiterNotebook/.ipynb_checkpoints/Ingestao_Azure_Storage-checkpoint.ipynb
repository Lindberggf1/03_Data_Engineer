# %% [markdown]
# ## Passo 1: Importar a base de dados

# %%
import pandas as pd

# %%
##tabela_clientes = pd.read_csv(r"C:\Users\lindb\Python-Estudos\Analise_de_Dados_Python\Arquivos\telecom_users.csv")

tabela_clientes = pd.read_csv(r"Arquivos\telecom_users.csv")

# %% [markdown]
# ## Passo 2: Visualizar a base de dados para entender o que temos disponível

# %%
display(tabela_clientes)
# Out:
#       Unnamed: 0   IDCliente     Genero  Aposentado Casado Dependentes  \
# 0           1869  7010-BRBUU  Masculino           0    Sim         Sim
# 1           4528  9688-YGXVR   Feminino           0    Nao         Nao
# 2           6344  9286-DOJGF   Feminino           1    Sim         Nao
# 3           6739  6994-KERXL  Masculino           0    Nao         Nao
# 4            432  2181-UAESM  Masculino           0    Nao         Nao
# ...          ...         ...        ...         ...    ...         ...
# 5981        3772  0684-AOSIH  Masculino           0    Sim         Nao
# 5982        5191  5982-PSMKW   Feminino           0    Sim         Sim
# 5983        5226  8044-BGWPI  Masculino           0    Sim         Sim
# 5984        5390  7450-NWRTR  Masculino           1    Nao         Nao
# 5985         860  4795-UXVCJ  Masculino           0    Nao         Nao
#
#       MesesComoCliente ServicoTelefone MultiplasLinhas ServicoInternet  ...  \
# ...

# %% [markdown]
# ## Passo 3: Enviar para Blob Storag

# %%
# !pip install azure.functions
# !pip install azure.storage.blob
# !pip install azure-storage-file-datalake
# Out:
# ...
#   Using cached azure_functions-1.11.2-py3-none-any.whl (206 kB)
# ...
#   Using cached azure_storage_blob-12.12.0-py3-none-any.whl (366 kB)
# ...
#   Using cached msrest-0.7.1-py3-none-any.whl (85 kB)
# ...
#   Using cached azure_core-1.24.1-py3-none-any.whl (178 kB)
# ...
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# ...
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# ...
#   Using cached azure_storage_file_datalake-12.7.0-py3-none-any.whl (224 kB)
# ...

# %%
# !pip install python-dotenv

# %%
import logging
import os
from io import StringIO
import pandas as pd
from datetime import datetime, timedelta

# %%
import azure.functions as func
from azure.storage.blob import BlobServiceClient

# %%
import os, uuid
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient

# %%
import os, uuid, sys
from azure.storage.filedatalake import DataLakeServiceClient
from azure.core._match_conditions import MatchConditions
from azure.storage.filedatalake._models import ContentSettings

# %%
stg_con_str = "DefaultEndpointsProtocol=https;AccountName=stgestudos;AccountKey=AAYIb2CwhwDkluwkWeNmc88rLSjl5SAra8qzFoFMxO0USdP6qWlz8HFyrgFtO5DR/8vEsazpNhYa+AStToQC9w==;EndpointSuffix=core.windows.net"

# %%
blob_account_name = "stgestudos" # fill in your blob account name
blob_account_key = "AAYIb2CwhwDkluwkWeNmc88rLSjl5SAra8qzFoFMxO0USdP6qWlz8HFyrgFtO5DR/8vEsazpNhYa+AStToQC9w=="  # fill in your blob account key
mycontainer = "lindberg-ferreira"       # fill in the container name
myblobname = "lab04"        # fill in the blob name
mydatafile = "telecom_users.csv"        # fill in the output file name

# %%
#configurações de conexao do blob e notebook
stg_accot = 'stgestudos' #dbutils.secrets.get(scope='scopecobrapy', key='url-stgacct')
mycontainer = "lindberg-ferreira"
#key_storag = 'ynM4cxIqdy9MPzvu6fT+EkgNFhte1wkciWr0zT9V2YRlRGrcFV2+W9RgBU6IquJfwDCtIE9UpbY+onSmqeYUgg=='
key_storag = 'AAYIb2CwhwDkluwkWeNmc88rLSjl5SAra8qzFoFMxO0USdP6qWlz8HFyrgFtO5DR/8vEsazpNhYa+AStToQC9w=='
stg_blob_conn = "wasbs://" + mycontainer + "@" + stg_accot + ".blob.core.windows.net/orders.csv"

# %%
STORAGEACCOUNTURL= mycontainer + "@" + stg_accot + ".blob.core.windows.net"
STORAGEACCOUNTKEY= key_storag
LOCALFILENAME= "telecom_users.csv"
CONTAINERNAME= mycontainer
BLOBNAME= "telecom_users.csv"

# %%
import pandas as pd
import io
from azure.storage.blob import *

# %%
import dotenv

# %%
output = io.StringIO()
head = ["col1" , "col2" , "col3"]
l = [[1 , 2 , 3],[4,5,6] , [8 , 7 , 9]]
df = pd.DataFrame (l , columns = head)
print(df)
output = df.to_csv (index_label="idx", encoding = "utf-8")
print(output)

accountName = 'stgestudos'
accountKey = 'AAYIb2CwhwDkluwkWeNmc88rLSjl5SAra8qzFoFMxO0USdP6qWlz8HFyrgFtO5DR/8vEsazpNhYa+AStToQC9w=='
containerName = "lindberg-ferreira"
blobName = "test3.json"

blobService = BlockBlobService(account_name=accountName, account_key=accountKey)

blobService.create_blob_from_text('test1', 'OutFilePy.csv', output)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     8     7     9
# idx,col1,col2,col3
# 0,1,2,3
# 1,4,5,6
# 2,8,7,9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 14>()
#      11 containerName = "/mnt/lindberg-ferreira/lab04"
#      12 blobName = "test3.json"
# ---> 14 blobService = BlockBlobService(account_name=accountName, account_key=accountKey)
#      16 blobService.create_blob_from_text('test1', 'OutFilePy.csv', output)
#
# NameError: name 'BlockBlobService' is not defined

# %%
dotenv.load_dotenv()
blob_block = ContainerClient.from_connection_string(
    conn_str=os.environ['wasbs://lindberg-ferreira@stgestudos.blob.core.windows.net'],
    container_name=os.environ['/mnt/lindberg-ferreira/lab04']
    )
output = io.StringIO()
partial = df.DataFrame()
output = partial.to_csv(encoding='utf-8')
blob_block.upload_blob(name, output, overwrite=True, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 dotenv.load_dotenv()
#       2 blob_block = ContainerClient.from_connection_string(
# ----> 3     conn_str=os.environ['wasbs://lindberg-ferreira@stgestudos.blob.core.windows.net'],
#       4     container_name=os.environ['/mnt/lindberg-ferreira/lab04']
#       5     )
#       6 output = io.StringIO()
#       7 partial = df.DataFrame()
#
# File ~\anaconda3\lib\os.py:679, in _Environ.__getitem__(self, key)
#     676     value = self._data[self.encodekey(key)]
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'wasbs://lindberg-ferreira@stgestudos.blob.core.windows.net'
